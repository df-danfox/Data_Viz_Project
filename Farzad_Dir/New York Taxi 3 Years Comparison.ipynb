# %%
# Dependencies
import pandas as pd
from IPython.display import display
from IPython.display import Image
import requests
import json
import pprint
import seaborn as sns
import sys
import matplotlib.pyplot as plt
from functools import reduce

# %%
# 2016 Yellow Taxi Trip Data
url2016 = "https://data.cityofnewyork.us/resource/uacg-pexx.json"

data = url1

df = pd.read_json(url2016, orient='columns')
df1 = pd.read_json(url2016, orient='columns')
#df.head()
#pd.read_json(url2016, orient='columns').head()

# %%
# 2017 Yellow Taxi Trip Data
url2017 = "https://data.cityofnewyork.us/resource/biws-g3hs.json"

data = url2017

df = pd.read_json(url2017, orient='columns')
df2 = pd.read_json(url2017, orient='columns')
#df.head()
#pd.read_json(url2017, orient='columns').head()

# %%
# 2018 Yellow Taxi Trip Data
url2018 = "https://data.cityofnewyork.us/resource/t29m-gskq.json"

data = url2018

df = pd.read_json(url2018, orient='columns')
df3 = pd.read_json(url2018, orient='columns')

#df.head()
#pd.read_json(url2018, orient='columns').head()

# %%
len(df1)
# Out:
# 1000

# %%
df1.columns
# Out:
# Index(['dropoff_latitude', 'dropoff_longitude', 'extra', 'fare_amount',
#        'improvement_surcharge', 'mta_tax', 'passenger_count', 'payment_type',
#        'pickup_latitude', 'pickup_longitude', 'ratecodeid',
#        'store_and_fwd_flag', 'tip_amount', 'tolls_amount', 'total_amount',
#        'tpep_dropoff_datetime', 'tpep_pickup_datetime', 'trip_distance',
#        'vendorid'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['dolocationid', 'extra', 'fare_amount', 'improvement_surcharge',
#        'mta_tax', 'passenger_count', 'payment_type', 'pulocationid',
#        'ratecodeid', 'store_and_fwd_flag', 'tip_amount', 'tolls_amount',
#        'total_amount', 'tpep_dropoff_datetime', 'tpep_pickup_datetime',
#        'trip_distance', 'vendorid'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['dolocationid', 'extra', 'fare_amount', 'improvement_surcharge',
#        'mta_tax', 'passenger_count', 'payment_type', 'pulocationid',
#        'ratecodeid', 'store_and_fwd_flag', 'tip_amount', 'tolls_amount',
#        'total_amount', 'tpep_dropoff_datetime', 'tpep_pickup_datetime',
#        'trip_distance', 'vendorid'],
#       dtype='object')

# %%
pd.concat([df1, df2, df3], axis=1)
# Out:
#      dropoff_latitude  dropoff_longitude  extra  fare_amount  \
# 0           40.645329         -73.776299    0.0         52.0
# 1           40.754620         -73.993629    0.5         16.0
# 2           40.716316         -73.991966    0.0         12.5
# 3           40.785648         -73.969841    0.0         11.0
# 4           40.789509         -73.952454    0.0          7.0
# 5            0.000000           0.000000    0.5          6.5
# 6           40.756382         -73.968498    0.0         11.0
# 7           40.746746         -73.892387    0.5          8.5
# 8           40.780521         -73.961807    0.0          7.0
# 9           40.755192         -73.926857    0.5         40.5
# 10          40.757053         -73.975601    0.0          8.5
# 11          40.750050         -73.991699    0.0          7.0
# 12          40.752659         -73.978981    1.0          5.5
# 13          40.750130         -73.994911    1.0          4.5
# ...

# %%
# a scatter plot comparing total_amount and tip_amount
df.plot(kind='scatter',x='total_amount',y='tip_amount',color='red')
plt.show()

# %%
# a scatter plot comparing total_amount and trip_distance
df.plot(kind='scatter',x='total_amount',y='trip_distance',color='red')
plt.show()

# %%
# a scatter plot comparing fare_amount and tip_amount
df.plot(kind='scatter',x='fare_amount',y='tip_amount',color='blue')
plt.show()
