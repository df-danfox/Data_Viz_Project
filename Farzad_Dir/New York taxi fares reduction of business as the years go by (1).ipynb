# %%
# Dependencies
import requests
import json
import pprint
import pandas as pd
import sys
import matplotlib.pyplot as plt

# %%
# 2016 Yellow Taxi Trip Data
url1 = "https://data.cityofnewyork.us/resource/uacg-pexx.json"

data = url1

df = pd.read_json(url1, orient='columns')

df.head()
pd.read_json(url1, orient='columns').head()
# Out:
#    dropoff_latitude  dropoff_longitude  extra  fare_amount  \
# 0         40.645329         -73.776299    0.0         52.0
# 1         40.754620         -73.993629    0.5         16.0
# 2         40.716316         -73.991966    0.0         12.5
# 3         40.785648         -73.969841    0.0         11.0
# 4         40.789509         -73.952454    0.0          7.0
#
#    improvement_surcharge  mta_tax  passenger_count  payment_type  \
# 0                    0.3      0.5                1             1
# 1                    0.3      0.5                1             1
# 2                    0.3      0.5                1             1
# 3                    0.3      0.5                1             2
# 4                    0.3      0.5                1             1
#
#    pickup_latitude  pickup_longitude  ratecodeid store_and_fwd_flag  \
# 0        40.829857        -73.948257           2                  N
# 1        40.721790        -73.988251           1                  N
# 2        40.710545        -73.957199           1                  N
# 3        40.766010        -73.979858           1                  N
# 4        40.780270        -73.946999           1                  N
#
#    tip_amount  tolls_amount  total_amount    tpep_dropoff_datetime  \
# 0        5.00          5.54         63.34  2016-03-11T03:57:14.000
# 1        2.70          0.00         20.00  2016-03-04T23:20:10.000
# 2        2.65          0.00         15.95  2016-03-22T08:57:35.000
# 3        0.00          0.00         11.80  2016-03-22T15:00:06.000
# 4        1.00          0.00          8.80  2016-03-21T07:04:40.000
#
#       tpep_pickup_datetime  trip_distance  vendorid
# 0  2016-03-11T03:23:36.000          20.30         1
# 1  2016-03-04T22:57:59.000           3.22         2
# 2  2016-03-22T08:39:17.000           2.30         1
# 3  2016-03-22T14:45:11.000           1.75         2
# 4  2016-03-21T06:56:40.000           0.97         2

# %%
# 2016 Yellow Taxi Trip Data
df.plot(kind='scatter',x='total_amount',y='tip_amount',color='red')
plt.show()

# %%
# 2017 Yellow Taxi Trip Data
url = "https://data.cityofnewyork.us/resource/biws-g3hs.json"

data = url

df = pd.read_json(url, orient='columns')

df.head()
# Out:
#    dolocationid  extra  fare_amount  improvement_surcharge  mta_tax  \
# 0           161    0.5          4.5                    0.3      0.5
# 1           246    0.5         13.5                    0.3      0.5
# 2           162    0.5          4.5                    0.3      0.5
# 3           237    0.5          8.0                    0.3      0.5
# 4           137    0.5          8.0                    0.3      0.5
#
#    passenger_count  payment_type  pulocationid  ratecodeid store_and_fwd_flag  \
# 0                1             1           162           1                  N
# 1                1             1           114           1                  N
# 2                4             1           237           1                  N
# 3                6             2           142           1                  N
# 4                2             1           162           1                  N
#
#    tip_amount  tolls_amount  total_amount    tpep_dropoff_datetime  \
# 0        1.16           0.0          6.96  2017-02-15T21:16:49.000
# 1        2.96           0.0         17.76  2017-02-15T21:28:24.000
# 2        1.16           0.0          6.96  2017-02-15T21:16:18.000
# 3        0.00           0.0          9.30  2017-02-15T21:21:50.000
# 4        1.86           0.0         11.16  2017-02-15T21:21:35.000
#
#       tpep_pickup_datetime  trip_distance  vendorid
# 0  2017-02-15T21:13:02.000           0.64         2
# 1  2017-02-15T21:13:02.000           3.03         2
# 2  2017-02-15T21:13:02.000           0.46         2
# 3  2017-02-15T21:13:02.000           1.31         2
# 4  2017-02-15T21:13:02.000           1.71         2

# %%
# 2017 Yellow Taxi Trip Data
# a scatter plot comparing trip_distance and total_amount
df.plot(kind='scatter',x='total_amount',y='tip_amount',color='red')
plt.show()

# %%
# 2018 Yellow Taxi Trip Data
url = "https://data.cityofnewyork.us/resource/t29m-gskq.json"

data = url

df = pd.read_json(url, orient='columns')

df.head()
# Out:
#    dolocationid  extra  fare_amount  improvement_surcharge  mta_tax  \
# 0           236    0.0         10.0                    0.3      0.5
# 1           236    0.0         10.0                    0.3      0.5
# 2           238    0.0          4.0                    0.3      0.5
# 3           238    0.0          4.0                    0.3      0.5
# 4           238    0.0         10.0                    0.3      0.5
#
#    passenger_count  payment_type  pulocationid  ratecodeid store_and_fwd_flag  \
# 0                1             2           238           1                  N
# 1                1             2           238           1                  N
# 2                1             2           238           1                  N
# 3                1             2           238           1                  N
# 4                1             2           236           1                  N
#
#    tip_amount  tolls_amount  total_amount    tpep_dropoff_datetime  \
# 0         0.0           0.0          10.8  2084-11-04T12:47:41.000
# 1         0.0           0.0          10.8  2084-11-04T12:47:41.000
# 2         0.0           0.0           4.8  2084-11-04T12:29:00.000
# 3         0.0           0.0           4.8  2084-11-04T12:29:00.000
# 4         0.0           0.0          10.8  2084-11-04T12:22:24.000
#
#       tpep_pickup_datetime  trip_distance  vendorid
# 0  2084-11-04T12:32:24.000           1.34         2
# 1  2084-11-04T12:32:24.000           1.34         2
# 2  2084-11-04T12:25:53.000           0.32         2
# 3  2084-11-04T12:25:53.000           0.32         2
# 4  2084-11-04T12:08:33.000           1.85         2

# %%
# 2018 Yellow Taxi Trip Data
# a scatter plot comparing total_amount and tip_amount
df.plot(kind='scatter',x='total_amount',y='tip_amount',color='red')
plt.show()
